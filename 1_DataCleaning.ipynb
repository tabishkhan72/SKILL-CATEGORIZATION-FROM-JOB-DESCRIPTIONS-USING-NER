# %% [markdown]
# # Notebook 1: Data Cleaning
#
# This is the first notebook, responsible for
# - Data Loading
# - Data Cleaning
# - Filtering only the required jobs descriptions by Job titles
# - Stop words removal
# - Tokenization
# - BIO Tagging
# - Extracting Skills from job description using Pattern Matching

# %% [markdown]
# # Imports

# %%
import pandas as pd
from google.colab import drive
from bs4 import BeautifulSoup
import ast
import spacy
from spacy.matcher import PhraseMatcher
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from tqdm import tqdm
tqdm.pandas(desc="Progress")

drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Mounted at /content/drive

# %% [markdown]
# # Data Loading

# %%
df1=pd.read_parquet("drive/Shareddrives/TM_project/jobpostings.parquet")
df2=pd.read_excel("drive/Shareddrives/TM_project/Technology Skills.xlsx")
df3=pd.read_excel("drive/Shareddrives/TM_project/Skills.xlsx")

# %%
df1.columns
# Out:
# Index(['Job Id', 'Job Title', 'Job Description', 'Company Name', 'Skills',
#        'Qualification', 'Website Url'],
#       dtype='object')

# %%
df1.head(10)
# Out:
#                              Job Id                      Job Title  \
# 0  89c41c519c3c491929e3082f0ee1d557           Editor, Celebrations
# 1  ac0c91f394fa77a00ad72ee3440cb4b7           Software Engineer II
# 2  4b5748411c4496f56ef33645a27840e0   Principal Software Architect
# 3  7a7dac1bc98365216833008c0fbd063d       Strategy Program Manager
# 4  304aff90fd39fead183f48206f4070c7        Senior Contract Manager
# 5  f8e7c2fe7bfda8455ca2e18eb1beea5a       Newborn Hearing Screener
# 6  5c90575d962b567019643d4a8cea127f       Newborn Hearing Screener
# 7  d6583b8a3a0d7e72e884df39eda98576      Program Manager-Male Only
# 8  5c89e0132ec782188f22757c68c315a1  Senior Director, New Ventures
# 9  54d9be0a01d5c48a47116f5d527154fe             Research Associate
#
#                                      Job Description  \
# 0  <br/><br/>Gannett Co., Inc. (NYSE: GCI) is a s...
# 1  Overview </b>       <br/><br/>Reporting to the...
# 2  <br/> <br/>Digital technology has forever chan...
# 3  <br/> <br/> <b>Build your future with Sovos</b...
# 4  Description<br/> <br/>LaBella Associates was e...
# 5  Overview </b>       <br/><br/><b>Hearing Scree...
# 6  Overview </b>       <br/><br/><b>Hearing Scree...
# 7  Overview </b>       <br/><br/>The Program Mana...
# 8  Senior Director, New Ventures<br/>            ...
# 9  <br/><b>Research Associate</b><br/> <br/>Job L...
#
#                                  Company Name  \
# 0                                     Gannett
# 1                                         ERT
# 2                      Sovos Compliance, LLC.
# 3                      Sovos Compliance, LLC.
# 4                          LaBella Associates
# 5                                  Oticon USA
# 6                                  Oticon USA
# 7                                   Advocates
# 8  University of Massachusetts Medical School
# 9                          Forrester Research
#
#                                               Skills  \
# 0                 [Local Media, Editing, Journalism]
# 1  [Java, Application Architecture, CI, Data Stru...
# 2  [Java, CSS, Government Compliance, Global Comp...
# 3  [Government Compliance, Global Compliance, Com...
# 4                              [Legal, Disciplinary]
# 5         [Patient Care, vaccine, Nursing, Auditory]
# 6         [Patient Care, vaccine, Nursing, Auditory]
# 7      [Budgetary, Consultation, Budget Development]
# 8  [Business Strategy, IP management, c, Investme...
# 9                                          [Advisor]
#
#                                        Qualification               Website Url
# 0  [Bachelor of Journalism (B.J.), Master of Jour...   https://www.gannett.com
# 1            [Bachelor of Computer Science (B.C.S.)]        http://www.ert.com
# 2                                               None         https://sovos.com
# 3                                               None         https://sovos.com
# 4  [Bachelor of Engineering (B.E./B.Eng.), Any Ba...  http://www.labellapc.com
# 5                              [High School Diploma]     http://www.Oticon.com
# 6                              [High School Diploma]     http://www.Oticon.com
# 7                                               None  http://www.Advocates.org
# 8                                               None      https://umassmed.edu
# 9                                               None  http://www.forrester.com

# %%
all_jobs = df1["Job Title"].value_counts()
all_jobs_50 = all_jobs[all_jobs>30].index

# %%
len(all_jobs)
# Out:
# 86968

# %% [markdown]
# # Data Sampling

# %%
final_jobs=[
 'Software Engineer',
 'Senior Software Engineer',
 'Software Development Engineer',
 'Research Associate',
 'Financial Analyst',
 'Product Manager',
 'Business Analyst',
 'Business Development Representative',
 'Principal Software Engineer',
 'Data Engineer',
 'Data Scientist',
 'Mechanical Engineer',
 'Data Analyst',
 'Software Development Manager',
 'Senior Data Engineer',
 'Systems Engineer',
 'Associate Scientist',
 'Senior Product Manager',
 'Research Scientist',
 'Research Associate I',
 'DevOps Engineer',
 'Scientist',
 'Java Developer',
 'Software Engineer II',
 'Project Engineer',
 'Business Systems Analyst',
 'Program Director',
 'UX Designer',
 'Senior Program Manager',
 'Senior Software Development Engineer',
 'Engineer',
 'Software Developer',
 'Senior Business Analyst',
 'Senior Data Scientist'
]

# %%
len(final_jobs)
# Out:
# 34

# %%
df_filtered = df1[df1['Job Title'].isin(final_jobs)]

len(df_filtered)
# Out:
# 2288

# %% [markdown]
# # Data Cleaning

# %%
df_filtered[df_filtered["Job Description"].isnull()]
# Out:
#                                   Job Id                 Job Title  \
# 113987  745c1de8aa6f17d56f9d7d2f845295d2         Financial Analyst
# 113991  6e707ea06537b3e4aa4d08ecfe64ef4e           Product Manager
# 113992  e2b53279e438915f1802305a552cda9a  Senior Software Engineer
# 122594  a8b413e57da4cc26b1c38842964c7b6c              Data Analyst
# 183685  21ca1e9bf16a7f12cf106f6595ad847c  Senior Software Engineer
#
#        Job Description                     Company Name  \
# 113987            None              Optima Bank & Trust
# 113991            None                         Facebook
# 113992            None                 Constant Contact
# 122594            None  Drift: Conversational Marketing
# 183685            None                 Constant Contact
#
#                                                    Skills  \
# 113987         [Wealth Management, Accounting, Budgeting]
# 113991  [Product Development, Product Requirements, Pr...
# 113992  [Java, CSS, UX, Unit Testing, Rex, CI, HTML, S...
# 122594  [Data Engineering, Scalability, Scala, Macro, ...
# 183685  [Java, CSS, UX, Unit Testing, Rex, CI, HTML, S...
#
#                                         Qualification  \
# 113987  [Bachelor of Finance, Bachelor of Accounting]
# 113991                                           None
# 113992                                           None
# 122594                                           None
# 183685                                           None
#
#                                      Website Url
# 113987                 http://www.optimabank.com
# 113991                   http://www.facebook.com
# 113992  http://www.constantcontact.com/index.jsp
# 122594                    https://www.drift.com/
# 183685  http://www.constantcontact.com/index.jsp

# %%
no_null_df=df_filtered[df_filtered["Job Description"].notnull()]

# %%
col=["Job Id", "Job Description","Skills"]
df1_filtered = no_null_df[col]

# %%
def parse_html_tags(job_description): #function to remove HTML tags
    soup = BeautifulSoup(str(job_description), 'html.parser')
    parsed_text = soup.get_text()
    return parsed_text

# %%
df1_filtered.loc[:, 'Job Description'] = df1_filtered['Job Description'].astype(str)
df1_filtered.loc[:, 'Job Description'] = df1_filtered['Job Description'].progress_apply(parse_html_tags)
# Out:
# <ipython-input-27-f5ed6fc09aab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_filtered.loc[:, 'Job Description'] = df1_filtered['Job Description'].astype(str)
# Progress: 100%|██████████| 2283/2283 [00:05<00:00, 400.13it/s]
# <ipython-input-27-f5ed6fc09aab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_filtered.loc[:, 'Job Description'] = df1_filtered['Job Description'].progress_apply(parse_html_tags)

# %%
df1_filtered['Skills'].iloc[0]
# Out:
# '[Java, Application Architecture, CI, Data Structures, Kafka, JSON, SQL, Data Integration, Software Development Life Cycle, Application Development, Software Development, DevOps, Databases, XML, Database, Data Analysis, API, Oracle, AWS, Framework, Python, RESTful]'

# %%
def parse_skills_corrected(skills_str):
    if isinstance(skills_str, str):
        skills_list = skills_str.strip('[]').split(', ')
        skills_list = [skill.strip(" '") for skill in skills_list]
        return skills_list
    else:
        # If it's not a string (e.g., NaN), return an empty list or whatever makes sense in your context
        return []

# Apply the function to the entire 'Skills' column
df1_filtered['Skills'] = df1_filtered['Skills'].apply(parse_skills_corrected)

# Show the DataFrame to verify the operation
df1_filtered
# Out:
# <ipython-input-29-4da8717f1eac>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_filtered['Skills'] = df1_filtered['Skills'].apply(parse_skills_corrected)
#                                   Job Id  \
# 1       ac0c91f394fa77a00ad72ee3440cb4b7
# 9       54d9be0a01d5c48a47116f5d527154fe
# 232     2092de5cc1d91311a39b1cae0fee9c09
# 333     46cbd86bab6441a53dee72855dc66ac6
# 422     3502aa5ac916ad02f655f0b8525e9013
# ...                                  ...
# 188578  90f107385cb990ffb9a3535a73bdd046
# 188584  39aa8aa59412afe6753354be5868c1aa
# 188619  9975bf695f0fe6204cbd6a726228bdd9
# 188624  f8fd3beb5dc778800272cf58aa9e8bb4
# 188626  cac387011b484822610fceae3f11f763
#
#                                           Job Description  \
# 1       Overview  Reporting to the Director of Data In...
# 9       Research Associate Job LocationsUS-MA-Cambridg...
# 232     Schneider Electric creates connected technolog...
# 333       Working Location:MASSACHUSETTS, WESTBOROUGH;...
# 422     job summary:  The Product Management Professio...
# ...                                                   ...
# 188578  Auto req ID 55553BR Job Code I0857P IT Busines...
# 188584  Auto req ID 55453BR Job Code I0758P Applicatio...
# 188619  Auto req ID 54782BR Job Code F0957P Financial ...
# 188624  Auto req ID 54656BR Job Code I0958P IT Infrast...
# 188626  Auto req ID 54538BR Job Code I0857P IT Busines...
#
#                                                    Skills
# 1       [Java, Application Architecture, CI, Data Stru...
# 9                                               [Advisor]
# 232                                                    []
# 333     [Data Engineering, Schema Design, Informatica,...
# 422     [Product Requirements, Product Management, Pro...
# ...                                                   ...
# 188578  [Information Systems, HTTP, BI Publisher, SQL,...
# 188584  [Unix, Query Optimization, Java, Methodologies...
# 188619  [Financial Analysis, Accounting, Budget Analys...
# 188624  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 188626  [User Acceptance Testing, Data Integrity, HTTP...
#
# [2283 rows x 3 columns]

# %%
job_ids=df1_filtered["Job Id"]

# %%
unique_job_ids = len(set(df1_filtered["Job Id"]))
unique_job_ids #All job IDs are unique
# Out:
# 2283

# %%
df1_filtered = df1_filtered.reset_index(drop=True)
df1_filtered.index += 1
df1_filtered['Job Id'] = df1_filtered.index
df1_filtered
# Out:
#       Job Id                                    Job Description  \
# 1          1  Overview  Reporting to the Director of Data In...
# 2          2  Research Associate Job LocationsUS-MA-Cambridg...
# 3          3  Schneider Electric creates connected technolog...
# 4          4    Working Location:MASSACHUSETTS, WESTBOROUGH;...
# 5          5  job summary:  The Product Management Professio...
# ...      ...                                                ...
# 2279    2279  Auto req ID 55553BR Job Code I0857P IT Busines...
# 2280    2280  Auto req ID 55453BR Job Code I0758P Applicatio...
# 2281    2281  Auto req ID 54782BR Job Code F0957P Financial ...
# 2282    2282  Auto req ID 54656BR Job Code I0958P IT Infrast...
# 2283    2283  Auto req ID 54538BR Job Code I0857P IT Busines...
#
#                                                  Skills
# 1     [Java, Application Architecture, CI, Data Stru...
# 2                                             [Advisor]
# 3                                                    []
# 4     [Data Engineering, Schema Design, Informatica,...
# 5     [Product Requirements, Product Management, Pro...
# ...                                                 ...
# 2279  [Information Systems, HTTP, BI Publisher, SQL,...
# 2280  [Unix, Query Optimization, Java, Methodologies...
# 2281  [Financial Analysis, Accounting, Budget Analys...
# 2282  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 2283  [User Acceptance Testing, Data Integrity, HTTP...
#
# [2283 rows x 3 columns]

# %%
job_id_simplified=df1_filtered['Job Id']

# %%
# Zipping the two lists together to create a new dataframe
zipped_df = pd.DataFrame(list(zip(job_ids, job_id_simplified)), columns=['Job Id', 'Job Id Simplified'])
zipped_df
merged_df_with_df_filtered = zipped_df.merge(df_filtered, on="Job Id", how="left")
merged_df_subset = merged_df_with_df_filtered[['Job Id', 'Job Id Simplified', 'Job Title']]
merged_df_subset.head()
# Out:
#                              Job Id  Job Id Simplified             Job Title
# 0  ac0c91f394fa77a00ad72ee3440cb4b7                  1  Software Engineer II
# 1  54d9be0a01d5c48a47116f5d527154fe                  2    Research Associate
# 2  2092de5cc1d91311a39b1cae0fee9c09                  3      Project Engineer
# 3  46cbd86bab6441a53dee72855dc66ac6                  4         Data Engineer
# 4  3502aa5ac916ad02f655f0b8525e9013                  5       Product Manager

# %% [markdown]
# # Creating Skill Taxonomy

# %%
list1 = list(set(sum(df1_filtered['Skills'].tolist(), [])))
len(list1)
# Out:
# 2022

# %%
list2=list(set(df2["Example"]))
len(list2)
# Out:
# 8869

# %%
list3=list(df3["Element Name"].unique())
list3
# Out:
# ['Reading Comprehension',
#  'Active Listening',
#  'Writing',
#  'Speaking',
#  'Mathematics',
#  'Science',
#  'Critical Thinking',
#  'Active Learning',
#  'Learning Strategies',
#  'Monitoring',
#  'Social Perceptiveness',
#  'Coordination',
#  'Persuasion',
#  'Negotiation',
#  'Instructing',
#  'Service Orientation',
#  'Complex Problem Solving',
#  'Operations Analysis',
#  'Technology Design',
#  'Equipment Selection',
#  'Installation',
#  'Programming',
#  'Operations Monitoring',
#  'Operation and Control',
#  'Equipment Maintenance',
#  'Troubleshooting',
#  'Repairing',
#  'Quality Control Analysis',
#  'Judgment and Decision Making',
#  'Systems Analysis',
#  'Systems Evaluation',
#  'Time Management',
#  'Management of Financial Resources',
#  'Management of Material Resources',
#  'Management of Personnel Resources']

# %%
complete_list=list1+list2+list3
lowercase_list = [string.lower() for string in complete_list]

# %%
full_list=list(set(lowercase_list))
len(lowercase_list),len(full_list)
# Out:
# (10926, 10758)

# %%
full_list.remove("auto")

# %%
fl=pd.Series(full_list)
fl.to_csv("skill_list.csv")

# %%
set(full_list)
# Out:
# {'distance learning software',
#  'shilstone seemix',
#  'lji technologies lumberjack',
#  'xfig',
#  'call accounting software',
#  'congruity technologies inspector',
#  'microsoft visual sourcesafe',
#  'server hardware',
#  'pyxis medstation software',
#  'eeo made simple aapmaker',
#  'forum one communications projectspaces',
#  'functional modeling software',
#  'refworks',
#  'airsmith flightprompt',
#  'algorithmic software',
#  'medmath',
#  'aquifer test software',
#  'power plants',
#  'second foundation navimeat',
#  'blackbaud luminate crm',
#  'adp hr/benefits solution',
#  'sparta systems trackwise',
#  'spring batch',
#  'honeywell wintress pacnet',
#  'meteorjs',
#  'oracle database',
#  'gaussian gaussview',
#  'inspection selection system iss',
#  'propertythree',
#  'hydrocad software solutions hydrocad',
#  'work record software',
#  'adobe systems adobe postscript',
#  'industrial production manager and stock control software',
#  'enterprise application integration eai software',
#  'inphase technologies group inphase concept',
#  'cbord nutrition service suite',
#  'transfection',
#  'water erosion prediction project wepp',
#  'wildland fire assessment system wfas',
#  'symantec altiris deployment solution',
#  'law enforcement database software',
#  'greenbrier graphics deed plotter',
#  'rsac riparian mapping tool',
#  'astrophysics',
#  'mvc architecture',
#  'emds practice partner',
#  'hash animation:master',
#  'codedcolor',
#  'hec-ras',
#  'programming',
#  'finance logix insurance planner',
#  'candidate tracking software',
#  'macvector',
#  'thomson reuters liquent insight suite',
#  'rescueconnection software shelterconntection',
#  'substation automation system software',
#  'authoria adviser',
#  'colasoft capsa free',
#  'niku clarity',
#  'deoxyribonucleic acid dna sequence analysis software',
#  'intravet',
#  'thomson reuters elite prolaw',
#  'virtual corporation sustainable planner',
#  'fbs data systems flexmls',
#  'zend framework',
#  'ravenshead services writeitnow',
#  'research spectrum survent cati',
#  'earthsoft equis geology',
#  'traffic control software',
#  'design strategy',
#  'vulcan solutions vulcan insurance',
#  'career cruising',
#  'scientific software group stepmaster',
#  'jtl enterprises medintake',
#  'data warehouse',
#  'openstack',
#  'geothermal properties measurement tool',
#  'thomson reuters clear',
#  'primasoft pc realtor organizer deluxe',
#  'narratek smartype',
#  'solar and wind energy resource assessment swera',
#  'right reason technologies righttrack',
#  'vertical solutions easy-farm accounting',
#  'cyber records medichart express',
#  'samarind rms',
#  'pii',
#  'prince2',
#  'red hat',
#  'bizmatics prognocis emr',
#  'terrain surface mapping software',
#  'zookeeper',
#  'the mathworks embedded coder',
#  'seimens healthineers',
#  'online computer library center oclc',
#  'deltek',
#  'analysis of smoke control systems ascos',
#  'evolution computing easycad',
#  'lakes environmental ecorisk view',
#  'docsite registry',
#  'ca idms',
#  'eden sales manager',
#  'siemens simatic wincc',
#  'ptc creo elements/pro',
#  'ciena software',
#  'apex business software ihr',
#  'traincaster lms',
#  'cabinet ng cng-safe',
#  'protocol design',
#  'scrum planning',
#  'mu',
#  'kika veracity',
#  'blat',
#  'stratitec timeips',
#  'field inspections',
#  'ibm websphere portal',
#  'jantek electronics jupiter time & attendance',
#  'mogo dental software mogo',
#  'meditech software',
#  'remote monitoring software',
#  'interpreter software',
#  'protocols',
#  'negative testing',
#  'dqo-pro',
#  'e-mds schedule',
#  'ibm ilog',
#  'access software airpax',
#  'microsoft platform',
#  'microsoft windows sdk',
#  'adobe systems adobe shockwave player',
#  'mastercontrol totalpharma',
#  'acclaim legal acclaim depomanage',
#  'rapid-i rapidminer',
#  'pc weather products hurrtrak',
#  'mentor graphics vesys design',
#  'solarwinds',
#  'national crime information center ncic',
#  'covirt virtgate',
#  'dsn software oral surgery-exec',
#  'hotel management',
#  'inventory software',
#  'ims specialty services ims digital office',
#  'golden software strater',
#  'golden software surfer (map creation feature)',
#  'sped forms',
#  'video encoder software',
#  'seacoast laboratory data systems surroundlab plus',
#  'ezclaim',
#  'adl data systems optimumclinicals electronic health record',
#  'microcog assessment of cognitive functioning',
#  'multiple options animal shelter management system',
#  'oclc illiad',
#  'collision damage measurement software',
#  'software quality assurance',
#  'software development tools',
#  'tanium software',
#  'thomson reuters gofileroom',
#  'pq systems sqcpack',
#  'tailwind management systems tailwind',
#  'computers unlimited tims for audiology',
#  'ovo studios ovo logger',
#  'cdi',
#  'creative solutions ultratax cs',
#  'originlab origin',
#  'dataxiom statmost',
#  'assisi software compiler',
#  'best mip fund accounting',
#  'strong concepts teapac',
#  'database performance tuning',
#  'drillingsoftware drillpro',
#  'aptean made2manage',
#  'statistical energy analysis sea software',
#  'electronic packaging',
#  'countryside data ag payroll',
#  'metrix imageware surfacer',
#  'ms project',
#  'datadescription datadesk',
#  'ubi biotracker',
#  'jenkins',
#  'oxford reference online',
#  'fitnesse',
#  'antek healthware labdaq',
#  'quickpen ductdesigner 3d',
#  'central desktop',
#  'santa maria software counterman pro',
#  'workingartist systems workingartist',
#  'microsoft extensible application markup language (xaml)',
#  'lsa visual easy lean',
#  'general atomic and molecular electronic structure system gamess',
#  'mckesson horizon anatomic pathology',
#  'apache jmeter',
#  'deacom erp',
#  'vectorworks architect',
#  'energy efficient rehab advisor',
#  'prowess',
#  'data integrity',
#  'joomla',
#  'qad mfg/pro',
#  'plant management software',
#  'stage',
#  'cadence dracula',
#  'tave studio manager',
#  'summary systems fleet commander',
#  'azemus fs',
#  'genetic algorithm software',
#  'ia systems streamlend',
#  'sybase ianywhere sales anywhere',
#  'enterprise backup systems',
#  'psychology software tools mri simulator',
#  'epicor srm',
#  'esha research the food processor',
#  'device driver software',
#  'yardi',
#  'packet analysis software',
#  'ethereum',
#  'command alkon commandconcrete',
#  'geant4',
#  'gcs property assessment and tax billing',
#  'tyler technologies munis',
#  'manhattan supply chain process platform',
#  'pci geomatics software',
#  'safety integrity level sil software',
#  'idms account ability',
#  'aseptic technique',
#  'trinity software solutions beacon',
#  'aspx',
#  'blumbeg drafting libraries',
#  'openoffice.org',
#  'rdbms',
#  'data profiling',
#  'e-mds docman',
#  'riskmetrics group wealthbench',
#  'electron microscopy',
#  'loader',
#  'perkinelmer chemoffice chem3d',
#  'test equipment',
#  'instructure canvas',
#  'conest bidtrac',
#  'digital imaging system software',
#  'charm++',
#  'cadence orcad',
#  'calibration',
#  'teamcenter',
#  'objectif lune printshop mail',
#  'icode everest',
#  'saltire software floorright',
#  'triggers',
#  'vector fields opera-3d',
#  'homag woodwop',
#  'gslib',
#  'scientific software group minteqa2',
#  'xara x',
#  'blender',
#  'project charter',
#  'mcafee virusscan',
#  'insidesales.com',
#  'positive pay software',
#  'intuit quicken',
#  'bottom line loanmaster loan servicing',
#  'three-dimensional motion capture software',
#  'resourcemate plus',
#  'computer drawing software',
#  'sony sound forge',
#  'sand',
#  'postal boundary mapping software',
#  'imaging solutions',
#  'templates',
#  'help desk software',
#  'statistical solutions bmdp',
#  'national library of medicine docline',
#  'revision control software',
#  'assisi software assisi compiler',
#  'reliability engineering',
#  'hunterstone thesis',
#  'uni/care pro-filer',
#  'kentech kipware t cnc',
#  'prode pd-plus',
#  'materials inventory software',
#  'mastercam',
#  'soil mapping software',
#  'carecloud central',
#  'labelmaster software reg-trieve',
#  'client records software',
#  'apple iwork numbers',
#  'visual molecular dynamics vmd',
#  'autodesk mechanical',
#  'iiba',
#  'brb software horizonmis',
#  'financial calculators software',
#  'chempute software estpro',
#  'etakeoff',
#  'oracle fusion applications',
#  'joint prediction of operons jpop',
#  'flexbox',
#  'psychological testing software',
#  'scadex technologies maestro',
#  'pharmaceutical research',
#  'chemsw calibration pro',
#  'lyris hq web-analytics solution',
#  'proforce paralegal pro-pack',
#  'allied financial software act4advisors',
#  'mcnp dose assessment computer code',
#  'wideorbit',
#  'microsoft transact-structural query language t-sql',
#  'device net',
#  'harvard thermal tas',
#  'standardized general markup language sgml',
#  'sweep analysis software',
#  'pilot navigator software load balance',
#  'motion correction software',
#  'katsura shareware ks strobe tuner',
#  'industrial scientific inet',
#  'pstek',
#  'network analysis sinda-g',
#  'sendgrid',
#  'micro-press microstation powerdraft',
#  'teleradiology systems',
#  'actuate birt',
#  'boston bar systems corporation sonnet',
#  'autosys',
#  'test-driven development',
#  'symantec',
#  'ticket issuing software',
#  'forest metrix',
#  'asset management administration software',
#  'nwchem',
#  'smart',
#  'operating system process control software',
#  'kismet',
#  'vector drawing software',
#  'protiviti governance portal',
#  'chemicals and irrigation candi',
#  'software quality',
#  'ncr teradata warehouse miner',
#  'data logger software',
#  'geospatial data',
#  'cfos',
#  'grails',
#  'commercial finance',
#  'microsoft business contact manager',
#  'partech pixelpoint pos',
#  'united systems and software individual life and health administration system',
#  'systat software lisa.lims',
#  'midi maestro',
#  'capsher technology suretec',
#  'corona',
#  'question interchange profile quip software',
#  'sales operations',
#  'computerized numerical control cnc software',
#  'mcneel rhino software',
#  'php',
#  'electric vlsi design system',
#  'automatic test program generation atpg',
#  'cbord foodservice suite',
#  'sage software sage50',
#  'designer',
#  'manufacturing drawings',
#  'red hat openshift',
#  'allscripts pm',
#  'atdd',
#  'microsoft office outlook (calendar)',
#  'dsn software dental-exec',
#  'sungard assurance',
#  'thomson reuters web of science',
#  'photo editing software',
#  'land software customer pro-file',
#  'topaz software symplifi (crm feature)',
#  'objective caml',
#  'bamboo',
#  'on center quick bid',
#  'rockware rockworks',
#  'idl',
#  'projectlibre',
#  'teleo practice services the complete practitioner',
#  'cluen',
#  'benchmark systems benchmark clinical ehr',
#  'cognex',
#  'three-dimensional scanning software',
#  'forest vegetation simulator fvs',
#  'netstat',
#  'bentley geopak civil engineering suite',
#  'troubleshooting software',
#  'encite dermatology electronic health records ehr software',
#  'datafarm ectdviewer',
#  'autodesk 3d studio design',
#  'transpolink bidleads',
#  'navzilla',
#  'software development life cycle (sdlc)',
#  'microsoft active server pages asp',
#  'web conferencing software',
#  'jetbrains team city',
#  'radiant systems counterpoint',
#  'armon technologies xlactuary',
#  'fortherecord therecord player',
#  'cost estimating software',
#  'neurosolutions for matlab',
#  'data solutions',
#  'profitool gearwatch',
#  'huntersoft business translator',
#  'asi frontdesk',
#  'bio-logic systems hint pro',
#  'wonderware intouch hmi',
#  'avid digidesign pro tools',
#  'freight reservation software',
#  'augmint',
#  'programming language one pl/i',
#  'proscan',
#  'intellitrack 3pl',
#  'thomson endnote',
#  '3d nature llc visual nature studio',
#  'quantitative research',
#  'difequ',
#  'fire safety inspection and testing software',
#  'iterum emedic',
#  'telematics',
#  'dental product manufacturing software',
#  'maintenance reporting software',
#  'automated equipment identification aei software',
#  'corel ulead dvd workshop',
#  'production planning software',
#  'microsoft axapta',
#  'restful',
#  'askia analyse',
#  'backbone.js',
#  'teradata software',
#  'igrafx',
#  'valtamtech flight crew log',
#  'ibm tivoli',
#  'seomoz',
#  'oracle',
#  'oracle performance management suites',
#  'active listening',
#  'parthenon',
#  'phoenixpro forest activity tracking',
#  'graphite',
#  'qpuncture ii',
#  'fourier transform infrared ftir software',
#  'cgi-ams strata',
#  'data center',
#  'verbi maxqda',
#  'sage',
#  'dbase plus',
#  'cartesis es magnitude',
#  'ambient design artrage',
#  'alert technologies opscenter',
#  'exact software macola erp',
#  'conest t&m billing manager',
#  'mathematical software',
#  'baseline',
#  'gendex dental systems vixwin pro',
#  'xara xtreme',
#  'realtystar real estate assistant',
#  'cmt cogocad',
#  'discrete dynamics lab ddlab',
#  'easy dispatch',
#  'apache oozie',
#  'network instruments observer standard',
#  'cyberdyne industries casewizard',
#  'distribution management system dms',
#  'conarc ichannel',
#  'adobe systems adobe acrobat pro extended',
#  'palisade stattools',
#  'vector canalyzer',
#  'digital karyotyping software',
#  'statics',
#  'solar-2',
#  'sql server 2005',
#  "archivists' toolkit",
#  'mvc',
#  'due diligence',
#  'data extraction software',
#  'datapath dpisuite',
#  'testcafe',
#  'electro-mechanical design',
#  'data mapping',
#  'waters elab notebook',
#  'ppd patient profiles',
#  'naturaemed officepro',
#  'matrix calculation software',
#  'axistive bigshot screen magnifier',
#  'intrado schoolmessenger',
#  'cuadra associates star/museums',
#  'alfresco software alfresco',
#  'google slides',
#  'software ag',
#  'p-sea windplot',
#  'gravitation software',
#  'scalable vector graphics svg',
#  'open graphics library opengl',
#  'immunotherapy',
#  'crytek cryengine',
#  'sungard',
#  'component libraries',
#  'specialist data solutions octoplus',
#  'logisuite forwarder',
#  'medical wizards paramedics toolbox',
#  'video development software',
#  'splutterfish brazil',
#  'robotics academy robotc',
#  'communityviz',
#  'nolo quicken legal business pro',
#  'pearson powerschool',
#  'ex libris group aleph',
#  'waterloo hydrogeologic tactic',
#  'vehicle information databases',
#  'ncss power analysis and sample size pass',
#  'palmtree ems field reference guide',
#  'snorasson holdings ccnow',
#  'logistics support analysts smartlogic',
#  'web framework',
#  'argosy legal systems power closer',
#  'pelion manufacturing process optimization mpo software',
#  'moldraw',
#  'compliance testing software',
#  'ptc pro/cable',
#  'electrosoft flashworks',
#  'ruby',
#  'visionary medical systems visionary office pm',
#  'keltec systems herdmaster',
#  'blink',
#  'navigation software',
#  'ms*health software/cmhc',
#  'benaissance cobrapoint',
#  'walmart retail link',
#  'digital imaging communications in medicine dicom software/modality management software',
#  'fanuc cnc software',
#  'system center suite',
#  'geodetic software',
#  'writing queries',
#  'microsoft asp.net core mvc',
#  'noldus information technology facereader',
#  'biomechanical modeling software',
#  'automated auditors fraud detector software',
#  'sas software',
#  'iea software emerald',
#  'capistrano',
#  'wolfel immi',
#  'bowtie',
#  'materialise dental simplant',
#  'advantagelaw winvantage',
#  'junit',
#  'trane system analyzer',
#  'amadeus altea reservation',
#  'xifin',
#  'cdc supply chain',
#  'constant contact',
#  'hp webinspect',
#  'sokkia spectrum survey suite',
#  'musical palette',
#  'geoeas',
#  'biometrics video game software',
#  'express business valuations',
#  'qpsmr limited insight',
#  'mapinfo',
#  'questor systems qscan32',
#  'assisted model building with energy refinement amber',
#  'accuship star system',
#  'ibm rational requisite pro',
#  'land & sea dyno-max',
#  'issue tracking system software',
#  'equifax software',
#  'distributed caching',
#  'database security software',
#  'andersonbell abstat',
#  'docker',
#  'microsys micromd',
#  'mywritertools',
#  'relational database management system rdms',
#  'kintraks',
#  'petschedule',
#  'agile product lifecyle management plm',
#  'opencv',
#  'mi-assistant mi management system',
#  'design engineering',
#  'blumenthal software pbsw24',
#  'satellite image databases',
#  'sumquest',
#  'web scrapbook',
#  'primavera cost management',
#  'haisen software system',
#  'lamp',
#  'simcorp dimension',
#  'shazam',
#  'logger software',
#  'mobile design',
#  'aspentech aspen infoplus',
#  'funeralkiosk',
#  'national instruments multisim',
#  'data operations',
#  'ppe',
#  'spss',
#  'java performance',
#  'onecnc cad/cam',
#  'oracle manufacturing scheduling',
#  'mrx solutions officemaster',
#  'computerized inventory tracking software',
#  'discovery process',
#  'caliper maptitude',
#  'postgresql database',
#  'innova financial solutions derivatives expert',
#  'robotic control software',
#  'database applications',
#  'expressdigital labtricity',
#  'ibm judicial enforcement management system jems',
#  'microsoft visual interdev',
#  "standard & poor's capital iq compustat",
#  'real ear measurement rem software',
#  'perio charting software',
#  'local area network lan software',
#  'usda nrcs soil data viewer',
#  'automated payroll software',
#  'sales support',
#  'electromagnetic analysis software',
#  'hydrosolve aqtesolv',
#  'geoagro gis',
#  'pc-mapper software',
#  'web service development',
#  'practice-web dental',
#  'atlas search',
#  'business units',
#  'analog devices visualdsp++',
#  'posting software',
#  'guardian rfid',
#  'recovery audit software',
#  'synaptec lawbase case management',
#  'business performance management bpm software',
#  'financial analysis software',
#  'test automation',
#  'microsoft expression blend',
#  'atria smoke management engineering tools asmet',
#  'ge healthcare viewpoint for radiology',
#  'first notice systems claimcapture',
#  'digital analysis tests and statistics datas for excel',
#  'fuzebox',
#  'echurch.com schoolperfect',
#  'medcomsoft record',
#  "ashley software writer's blocks",
#  'hewlett packard loadrunner',
#  'systems monitoring',
#  'data mining software',
#  'cloud foundry',
#  'maplesoft maplesim',
#  'timberlake consultants oxmetrics',
#  'meat inventory software',
#  'computer aided software engineering case tools',
#  'budgeting software',
#  'excel',
#  'audio chaos soundscape generator',
#  'rand mcnally world digital database',
#  'typography',
#  'dtsearch',
#  'hypervisor',
#  'real-time reporting',
#  'private clouds',
#  'check processing software',
#  "ceejs the pet groomer's secretary",
#  'govern software land and permits management system',
#  'ios health systems medios ehr',
#  'xerces2 java parser',
#  'teradata sql',
#  'phase forward inform gtm',
#  'molecular devices softmax pro',
#  'bmc software recovery manager rman',
#  "cnc consulting machinists' calculator",
#  'rxkinetics ud labels for windows',
#  'brainstorming',
#  'rrc',
#  'midi score creator',
#  'electronic data interchange edi software',
#  'ibm rational clearquest',
#  'nfs',
#  'palisade bond @nalyst',
#  'avaaz innovations interactive voice analysis system ivans',
#  'application architecture',
#  'powerworld corporation powerworld simulator',
#  'sap businessobjects crystal reports',
#  'prezi',
#  'lenox softworks videopoint',
#  'positive train control ptc systems',
#  'g-cube solutions wizdom web lms',
#  'substance flow analysis stan',
#  'media storage management software',
#  'pisces iib',
#  'vortek site assessment of tornado threat satt',
#  'accounts receivables system software',
#  'paloalto advertising plan pro',
#  'xml authoring software',
#  'bmc software control-m',
#  'system3 pos software',
#  'marklogic',
#  'cropman',
#  'solidthinking',
#  'portswigger burp suite',
#  'microsoft visual basic for applications vba',
#  'mxi technologies maintenix',
#  'netreo omnicenter',
#  'schema design',
#  'opnet sp sentinel',
#  'laborsoft laborforce grievance manager module',
#  'literature & latte scrivener',
#  'accurate nxg',
#  'integrated decision support match advice',
#  'workschedule.net',
#  'perfusion',
#  'the general store',
#  'ewing solutions quickwriter',
#  'tradetec computer systems tallyworks logs',
#  'pdm',
#  'quark',
#  'coordination',
#  'quality control analysis',
#  'canonical launchpad',
#  'amazon web services (aws)',
#  'ibm informix',
#  'california infinite lps',
#  'materials testing software',
#  'network addressable storage nas software',
#  'modular mining systems dispatch',
#  'acupartner professional',
#  'dotproject',
#  'ibm rational build forge enterprise',
#  'abb optimize it predict & control',
#  'applied systems vision',
#  'intergraph plant design system pds',
#  'management accounting',
#  'genepattern',
#  'seismic visualization software',
#  'the mortgage office loan origination',
#  'camfit data limited microfit',
#  'interlock shutdown systems',
#  'file structure',
#  'active learning',
#  'datatel colleague',
#  'leica geosystems erdas imagine software',
#  'proforce highlight flyer master',
#  'microelectromechanical systems mems simulation software',
#  'pro writing aid',
#  'compuware clientvantage agentless monitoring',
#  'adobe systems adobe cold fusion',
#  'lucid iq',
#  'automatic dynamic incremental nonlinear analysis adina',
#  'turtle creek software goldenseal (calendar and scheduling feature)',
#  'qualcomm',
#  'realdata reia',
#  'chromatography',
#  'fidelity hr/payroll',
#  'tadpoles',
#  "skyscape rosen and barkin's 5-minute emergency medicine consult",
#  'molecular devices corporation metamorph',
#  'random forest software',
#  'microsoft windows server',
#  'ebsco publishing academic search premier',
#  'jet',
#  'eye tracking exercises enterprises track with letters',
#  'altera hardware description language ahdl',
#  'paleotax',
#  'flatiron',
#  'two-dimensional 2d computer aided design cad software',
#  'power system modeling software',
#  'financial functions',
#  'trivantis lectora',
#  'vcg pointwing',
#  'datacom software business products m.i.s. clinic',
#  'celera assembler',
#  'pivotal',
#  'autodesk viz',
#  'steinberg cubase pro',
#  'water soil and hydro-environmental decision support system watershedss',
#  'ascend property assessment',
#  'commercial plate reader software',
#  'machineworks ltd. machineworks',
#  'kodak dental systems kodak practiceworks practice management software pms',
#  'silverbyte systems optima property management system pms',
#  'saas surveymonkey',
#  'vantage mcif',
#  'getting things done gtd software',
#  'geometric technologies camworks',
#  'computer-assisted career guidance software',
#  'revision control system',
#  'paisley risknavigator',
#  'mlpu',
#  'learn.com learncenter talent management suite',
#  'sst development group stratus',
#  'consulting engineering',
#  'ipswitch whatsup gold',
#  'card key management software',
#  'avenista table reservations',
#  'digital control systems dcs',
#  'syspro',
#  'drillingsoftware tubular database',
#  'system enhancements',
#  'aircraft noise monitoring system software',
#  'recipe software',
#  'grammarly editor',
#  'blinkbid',
#  'bruker axs topas',
#  'symantec pcanywhere',
#  'microsoft windows xp professional',
#  'thermo toxlab',
#  'merlinco merlin',
#  'computational dynamics star-cd',
#  'pepid rn critical care rncc',
#  'adobe systems adobe contribute',
#  'autodesk powermill',
#  'avid audio pro tools',
#  'molecular devices corporation metafluor',
#  'unidata gempak analysis and rendering program garp',
#  'mass flux toolkit',
#  'ppo',
#  'techhackers convertible bond @nalyst',
#  'mitchell manager invoicing system',
#  'ppt4drs quixote',
#  'damen damos',
#  'flying popcorn',
#  'gazebo',
#  'solutions by design screenplay',
#  'mra technologies mratrack warehouse management system',
#  'object oriented programming software',
#  'procedure scheduling software',
#  'autocrit editing wizard',
#  'riverbed technology',
#  'star team',
#  'nuview systems nuviewhr',
#  'career dimensions focus 2',
#  'stat-ease design-ease',
#  'recrystallize crystal reports',
#  'host analytics host budget',
#  'cimatron',
#  'dfd',
#  'impromed infinity',
#  'video retrieval systems',
#  'ramquest total solution',
#  'comcon datafriend',
#  'ardexus tasc',
#  'apache kafka',
#  'marketing analytics',
#  'bentley systems autopipe',
#  'mapr converged data platform',
#  'shortcuts software shortcuts spa',
#  'mapscenes pro',
#  'project.net',
#  'speech analysis software',
#  'windows/linux',
#  'notam development group airport insight',
#  'medquist docqment enterprise platform',
#  'advantage software podiatry advantage',
#  'espsoftware employee schedule partner',
#  'systemware',
#  'medgen ped',
#  'intellij idea',
#  'disk file systems',
#  'automated targeting system ats',
#  'data intelligence',
#  'human resources information system hris',
#  'synopsys tetramax atpg',
#  'accelrys decipher',
#  'oracle master data management mdm suite',
#  'brightwork alyce claims systems',
#  'laserfiche avante',
#  'structure prediction software',
#  'micros systems opera enterprise solution oes',
#  'enterprise software systems cre sync',
#  'gene regulation',
#  'xilinx modelsim',
#  'geosoft dap server',
#  'blackhawk canyon publishers practicianworks',
#  'build automation',
#  'time series modeling tsm software',
#  'alcestis',
#  'molecular simulation software',
#  'onset computer corporation hoboware',
#  'desktop publishing software',
#  'life cycle cost software',
#  'adobe systems adobe creative cloud',
#  'etq reliance',
#  'mirs compliance',
#  'ihs kingdom',
#  'rezgo',
#  'spring jdbc',
#  'orcad capture',
#  'asi point of sale',
#  'vieux & associates vflow',
#  'operations management',
#  'laboratory information management system (lims)',
#  'emboss',
#  'financial planning',
#  'wise solutions wise for windows installer',
#  'clinical software',
#  'image enhancement software',
#  'tourwriter',
#  'freeze.com ovation studio pro',
#  'consolidated model of fire and smoke transport cfast',
#  'oracle e-business suite',
#  'valiant vantage',
#  'kentech kipware m cnc',
#  'sage mip fund accounting',
#  'nch software express invoice',
#  'oracle peoplesoft',
#  'bing ads',
#  'elite software outpoint',
#  'finite element method fem software',
#  'hexagon metrology pc-dmis',
#  'ct hcue',
#  'highly analytical',
#  'clarified networks clarified analyzer',
#  'apple dvd studio pro',
#  'hyperion',
#  'j1939',
#  'juniper networks netscreen-security manager',
#  'paisley autoaudit',
#  'web security',
#  'scc soft computer softbank',
#  'schneider electric citectscada',
#  'requirements analysis software',
#  'advanced logic technology wellcad',
#  'presagia sports',
#  'swot',
#  'ups intelliverse',
#  'routing software',
#  'psychassistant',
#  'ics software sammyusa',
#  'sweetware stockcoster',
#  'palm os',
#  'hypack dredgepack',
#  'wireless networking',
#  'optimization software',
#  'tableau',
#  'network management software',
#  'technical product management',
#  'desire2learn',
#  'scc soft computer softpath',
#  'recruittrack',
#  'unawave',
#  'winners programs uni-stud',
#  'fractal concept softscan',
#  'remote deposit capture software',
#  'secure communications',
#  'technical perspectives class iep program',
#  'mesh generation software',
#  'electromechanical design',
#  'sound pressure analysis equipment',
#  'omicron test universe',
#  'information systems integration software',
#  'filehold systems filehold',
#  'technical architecture',
#  'autodesk autocad blue sky',
#  'internet of things',
#  'ge healthcare centricity laboratory transfusion medicine',
#  'infovision amlib',
#  'micros systems opera property management system pms',
#  'websphere application server',
#  'developer tools',
#  'galilee enterprise targetpro',
#  'kotlin',
#  'zabbix',
#  'web page design software',
#  'wiredred software e/pop basic',
#  'custom software systems starlab',
#  'statistics',
#  'usycams',
#  'splunk enterprise',
#  'soft essentials vending essentials',
#  'business-to-business',
#  'certain',
#  'netapp',
#  'worldcat',
#  'truepianos',
#  'computer records systems',
#  'data dissemination',
#  'linkedin',
#  'peopleclick caams',
#  'mapshots easi suite',
#  'data transfer software',
#  'raosoft surveywin',
#  'care paths erecord',
#  'on center on-screen takeoff',
#  'trimble gps pathfinder',
#  'sentai pinpoint',
#  'open data',
#  'ibm bpm blueprint',
#  'location mapping software',
#  'energy analysis software',
#  'check sorting control software',
#  'pxi',
#  'database design software',
#  'resource and patient management system rpms patient registration software',
#  'etelenext lis',
#  'minisis mint',
#  'solidworks enterprise pdm',
#  'ncr advanced checkout solution',
#  'hardware description and verification language',
#  'en route descent advisor eda',
#  'static strength prediction software',
#  'mediasoft medioffice',
#  'content filter software',
#  'conest surecount',
#  'time and motion analysis software',
#  'dun and bradstreet global decisionmaker',
#  'oracle e-business suite supply chain management',
#  'ez-zone optizone enterprise',
#  'educational software',
#  ...}

# %% [markdown]
# # Stop word removal and Tokenization

# %%
df1_filtered['Job Description'] = df1_filtered['Job Description'].str.lower()

# Load stopwords
stop_words = set(stopwords.words('english'))

# Define a function to tokenize and remove stopwords
def tokenize_and_remove_stopwords(description):
    sentences = sent_tokenize(description)
    return [[word for word in word_tokenize(sentence) if word not in stop_words] for sentence in sentences]

# Use 'apply' instead of a loop for better performance
tokenized_descriptions = df1_filtered["Job Description"].progress_apply(tokenize_and_remove_stopwords)
# Out:
# Progress: 100%|██████████| 2283/2283 [00:17<00:00, 133.79it/s]

# %%
df1_filtered["Tokenized Description"]=tokenized_descriptions
df1_filtered
# Out:
#       Job Id                                    Job Description  \
# 1          1  overview  reporting to the director of data in...
# 2          2  research associate job locationsus-ma-cambridg...
# 3          3  schneider electric creates connected technolog...
# 4          4    working location:massachusetts, westborough;...
# 5          5  job summary:  the product management professio...
# ...      ...                                                ...
# 2279    2279  auto req id 55553br job code i0857p it busines...
# 2280    2280  auto req id 55453br job code i0758p applicatio...
# 2281    2281  auto req id 54782br job code f0957p financial ...
# 2282    2282  auto req id 54656br job code i0958p it infrast...
# 2283    2283  auto req id 54538br job code i0857p it busines...
#
#                                                  Skills  \
# 1     [Java, Application Architecture, CI, Data Stru...
# 2                                             [Advisor]
# 3                                                    []
# 4     [Data Engineering, Schema Design, Informatica,...
# 5     [Product Requirements, Product Management, Pro...
# ...                                                 ...
# 2279  [Information Systems, HTTP, BI Publisher, SQL,...
# 2280  [Unix, Query Optimization, Java, Methodologies...
# 2281  [Financial Analysis, Accounting, Budget Analys...
# 2282  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 2283  [User Acceptance Testing, Data Integrity, HTTP...
#
#                                   Tokenized Description
# 1     [[overview, reporting, director, data, integra...
# 2     [[research, associate, job, locationsus-ma-cam...
# 3     [[schneider, electric, creates, connected, tec...
# 4     [[working, location, :, massachusetts, ,, west...
# 5     [[job, summary, :, product, management, profes...
# ...                                                 ...
# 2279  [[auto, req, id, 55553br, job, code, i0857p, b...
# 2280  [[auto, req, id, 55453br, job, code, i0758p, a...
# 2281  [[auto, req, id, 54782br, job, code, f0957p, f...
# 2282  [[auto, req, id, 54656br, job, code, i0958p, i...
# 2283  [[auto, req, id, 54538br, job, code, i0857p, b...
#
# [2283 rows x 4 columns]

# %% [markdown]
# # BIO Tagging

# %%
def get_bio_tags(lowercase_list, text_series):

    nlp = spacy.load("en_core_web_sm")
    matcher = PhraseMatcher(nlp.vocab)

    patterns = [nlp.make_doc(skill) for skill in lowercase_list]
    matcher.add("SKILL", None, *patterns)

    # Initialize an empty list to hold the BIO tags for each job description
    bio_tags_list = []
    for job_desc in tqdm(text_series):
        bio_tags_for_job_desc = []
        for sentence in job_desc:
            doc = spacy.tokens.Doc(nlp.vocab, words=sentence)
            bio_tags = ['O'] * len(doc)
            matches = matcher(doc)
            for match_id, start, end in matches:
                # Skip this match if it overlaps with a previous one
                if start > 0 and bio_tags[start - 1] in ('B', 'I'):
                    continue

                # The first token in the match gets a 'B' tag, the others get an 'I' tag
                bio_tags[start] = 'B'
                for i in range(start+1, end):
                    bio_tags[i] = 'I'
            bio_tags_for_job_desc.append(bio_tags)
        bio_tags_list.append(bio_tags_for_job_desc)

    return bio_tags_list

# %%
bt = get_bio_tags(full_list, df1_filtered["Tokenized Description"])
df1_filtered['tags']=bt
df1_filtered
# Out:
# 100%|██████████| 2283/2283 [00:04<00:00, 527.65it/s]
#       Job Id                                    Job Description  \
# 1          1  overview  reporting to the director of data in...
# 2          2  research associate job locationsus-ma-cambridg...
# 3          3  schneider electric creates connected technolog...
# 4          4    working location:massachusetts, westborough;...
# 5          5  job summary:  the product management professio...
# ...      ...                                                ...
# 2279    2279  auto req id 55553br job code i0857p it busines...
# 2280    2280  auto req id 55453br job code i0758p applicatio...
# 2281    2281  auto req id 54782br job code f0957p financial ...
# 2282    2282  auto req id 54656br job code i0958p it infrast...
# 2283    2283  auto req id 54538br job code i0857p it busines...
#
#                                                  Skills  \
# 1     [Java, Application Architecture, CI, Data Stru...
# 2                                             [Advisor]
# 3                                                    []
# 4     [Data Engineering, Schema Design, Informatica,...
# 5     [Product Requirements, Product Management, Pro...
# ...                                                 ...
# 2279  [Information Systems, HTTP, BI Publisher, SQL,...
# 2280  [Unix, Query Optimization, Java, Methodologies...
# 2281  [Financial Analysis, Accounting, Budget Analys...
# 2282  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 2283  [User Acceptance Testing, Data Integrity, HTTP...
#
#                                   Tokenized Description  \
# 1     [[overview, reporting, director, data, integra...
# 2     [[research, associate, job, locationsus-ma-cam...
# 3     [[schneider, electric, creates, connected, tec...
# 4     [[working, location, :, massachusetts, ,, west...
# 5     [[job, summary, :, product, management, profes...
# ...                                                 ...
# 2279  [[auto, req, id, 55553br, job, code, i0857p, b...
# 2280  [[auto, req, id, 55453br, job, code, i0758p, a...
# 2281  [[auto, req, id, 54782br, job, code, f0957p, f...
# 2282  [[auto, req, id, 54656br, job, code, i0958p, i...
# 2283  [[auto, req, id, 54538br, job, code, i0857p, b...
#
#                                                    tags
# 1     [[O, O, O, B, I, O, O, O, O, O, O, O, O, O, O,...
# 2     [[O, O, O, O, O, O, O, O, O], [O, O, O, O, O, ...
# 3     [[O, O, O, O, O, O, O, O, O, O, O, O, O], [O, ...
# 4     [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 5     [[O, O, O, B, I, O, O, O, O, O, B, O, O, O, O,...
# ...                                                 ...
# 2279  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
# 2280  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2281  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2282  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2283  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
#
# [2283 rows x 5 columns]

# %%
def extract_skills(tags_series, text_series):

    all_skills_found = []

    for tags, text in tqdm(zip(tags_series, text_series)):
        skills_found = []
        skill_phrase = []
        for sentence_tags, sentence in zip(tags, text):
            for word, tag in zip(sentence, sentence_tags):
                if tag == 'B':
                    # if a skill_phrase has been built, add it to skills_found
                    if skill_phrase:
                        skills_found.append(' '.join(skill_phrase))
                        skill_phrase = []
                    skill_phrase.append(word)
                elif tag == 'I':
                    skill_phrase.append(word)
        if skill_phrase:
            skills_found.append(' '.join(skill_phrase))

        unique_skills_found = list(set(skills_found))

        all_skills_found.append(unique_skills_found)
    return all_skills_found

# %%
skills = extract_skills(df1_filtered['tags'], df1_filtered["Tokenized Description"])
df1_filtered['found_skills']=skills
df1_filtered
# Out:
# 2283it [00:00, 7023.45it/s]
#       Job Id                                    Job Description  \
# 1          1  overview  reporting to the director of data in...
# 2          2  research associate job locationsus-ma-cambridg...
# 3          3  schneider electric creates connected technolog...
# 4          4    working location:massachusetts, westborough;...
# 5          5  job summary:  the product management professio...
# ...      ...                                                ...
# 2279    2279  auto req id 55553br job code i0857p it busines...
# 2280    2280  auto req id 55453br job code i0758p applicatio...
# 2281    2281  auto req id 54782br job code f0957p financial ...
# 2282    2282  auto req id 54656br job code i0958p it infrast...
# 2283    2283  auto req id 54538br job code i0857p it busines...
#
#                                                  Skills  \
# 1     [Java, Application Architecture, CI, Data Stru...
# 2                                             [Advisor]
# 3                                                    []
# 4     [Data Engineering, Schema Design, Informatica,...
# 5     [Product Requirements, Product Management, Pro...
# ...                                                 ...
# 2279  [Information Systems, HTTP, BI Publisher, SQL,...
# 2280  [Unix, Query Optimization, Java, Methodologies...
# 2281  [Financial Analysis, Accounting, Budget Analys...
# 2282  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 2283  [User Acceptance Testing, Data Integrity, HTTP...
#
#                                   Tokenized Description  \
# 1     [[overview, reporting, director, data, integra...
# 2     [[research, associate, job, locationsus-ma-cam...
# 3     [[schneider, electric, creates, connected, tec...
# 4     [[working, location, :, massachusetts, ,, west...
# 5     [[job, summary, :, product, management, profes...
# ...                                                 ...
# 2279  [[auto, req, id, 55553br, job, code, i0857p, b...
# 2280  [[auto, req, id, 55453br, job, code, i0758p, a...
# 2281  [[auto, req, id, 54782br, job, code, f0957p, f...
# 2282  [[auto, req, id, 54656br, job, code, i0958p, i...
# 2283  [[auto, req, id, 54538br, job, code, i0857p, b...
#
#                                                    tags  \
# 1     [[O, O, O, B, I, O, O, O, O, O, O, O, O, O, O,...
# 2     [[O, O, O, O, O, O, O, O, O], [O, O, O, O, O, ...
# 3     [[O, O, O, O, O, O, O, O, O, O, O, O, O], [O, ...
# 4     [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 5     [[O, O, O, B, I, O, O, O, O, O, B, O, O, O, O,...
# ...                                                 ...
# 2279  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
# 2280  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2281  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2282  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2283  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
#
#                                            found_skills
# 1     [application development, json, sql, data anal...
# 2     [application development, facebook, cio, twitt...
# 3     [software house, microsoft word, project manag...
# 4     [data science, data engineering, methodologies...
# 5     [product management, product requirements, des...
# ...                                                 ...
# 2279  [critical thinking, sql, https, data analysis,...
# 2280  [programming, debugging, data security, adviso...
# 2281  [budget management, oracle, project cost, micr...
# 2282  [ca, https, drawing, critical thinking, servic...
# 2283  [business analysis, ca, drawing, zoom, advisor...
#
# [2283 rows x 6 columns]

# %%
def get_missing_skills(skills, found_skills):
    # Convert both lists to lowercase sets for comparison
    skills_set = set(skill.lower() for skill in skills if isinstance(skill, str))
    found_skills_set = set(skill.lower() for skill in found_skills if isinstance(skill, str))
    # Find skills that are in 'skills' but not in 'found_skills'
    missing_skills = skills_set - found_skills_set
    return list(missing_skills)

# Apply the function to each row to create the new column 'ISNIFS'
df1_filtered['ISNIFS'] = df1_filtered.apply(lambda row: get_missing_skills(row['Skills'], row['found_skills']), axis=1)
df1_filtered
# Out:
#       Job Id                                    Job Description  \
# 1          1  overview  reporting to the director of data in...
# 2          2  research associate job locationsus-ma-cambridg...
# 3          3  schneider electric creates connected technolog...
# 4          4    working location:massachusetts, westborough;...
# 5          5  job summary:  the product management professio...
# ...      ...                                                ...
# 2279    2279  auto req id 55553br job code i0857p it busines...
# 2280    2280  auto req id 55453br job code i0758p applicatio...
# 2281    2281  auto req id 54782br job code f0957p financial ...
# 2282    2282  auto req id 54656br job code i0958p it infrast...
# 2283    2283  auto req id 54538br job code i0857p it busines...
#
#                                                  Skills  \
# 1     [Java, Application Architecture, CI, Data Stru...
# 2                                             [Advisor]
# 3                                                    []
# 4     [Data Engineering, Schema Design, Informatica,...
# 5     [Product Requirements, Product Management, Pro...
# ...                                                 ...
# 2279  [Information Systems, HTTP, BI Publisher, SQL,...
# 2280  [Unix, Query Optimization, Java, Methodologies...
# 2281  [Financial Analysis, Accounting, Budget Analys...
# 2282  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 2283  [User Acceptance Testing, Data Integrity, HTTP...
#
#                                   Tokenized Description  \
# 1     [[overview, reporting, director, data, integra...
# 2     [[research, associate, job, locationsus-ma-cam...
# 3     [[schneider, electric, creates, connected, tec...
# 4     [[working, location, :, massachusetts, ,, west...
# 5     [[job, summary, :, product, management, profes...
# ...                                                 ...
# 2279  [[auto, req, id, 55553br, job, code, i0857p, b...
# 2280  [[auto, req, id, 55453br, job, code, i0758p, a...
# 2281  [[auto, req, id, 54782br, job, code, f0957p, f...
# 2282  [[auto, req, id, 54656br, job, code, i0958p, i...
# 2283  [[auto, req, id, 54538br, job, code, i0857p, b...
#
#                                                    tags  \
# 1     [[O, O, O, B, I, O, O, O, O, O, O, O, O, O, O,...
# 2     [[O, O, O, O, O, O, O, O, O], [O, O, O, O, O, ...
# 3     [[O, O, O, O, O, O, O, O, O, O, O, O, O], [O, ...
# 4     [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 5     [[O, O, O, B, I, O, O, O, O, O, B, O, O, O, O,...
# ...                                                 ...
# 2279  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
# 2280  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2281  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2282  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2283  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
#
#                                            found_skills  \
# 1     [application development, json, sql, data anal...
# 2     [application development, facebook, cio, twitt...
# 3     [software house, microsoft word, project manag...
# 4     [data science, data engineering, methodologies...
# 5     [product management, product requirements, des...
# ...                                                 ...
# 2279  [critical thinking, sql, https, data analysis,...
# 2280  [programming, debugging, data security, adviso...
# 2281  [budget management, oracle, project cost, micr...
# 2282  [ca, https, drawing, critical thinking, servic...
# 2283  [business analysis, ca, drawing, zoom, advisor...
#
#                                                  ISNIFS
# 1      [databases, software development, framework, ci]
# 2                                                    []
# 3                                                    []
# 4                                    [rdbms, scripting]
# 5                                                    []
# ...                                                 ...
# 2279           [databases, data conversion, frameworks]
# 2280  [oracle, agile, http, problem solving, corona,...
# 2281                                                 []
# 2282  [http, aws, amazon web services (aws), corona,...
# 2283  [data integrity, http, corona, software soluti...
#
# [2283 rows x 7 columns]

# %%
df_with_isnifs = df1_filtered[df1_filtered['ISNIFS'].apply(len) > 0]

len(df_with_isnifs[['Skills', 'found_skills', 'ISNIFS']])
# Out:
# 1553

# %%
unique_skills_isnifs = set() #805 skills in total
for skills in df_with_isnifs['ISNIFS']:
    unique_skills_isnifs.update(skills)
skills_not_in_full_list = unique_skills_isnifs - set(full_list)

skills_not_in_full_list
# Out:
# set()

# %% [markdown]
# model errors
#
# Many skills in the skills column have not correctly been extracted by the pattern matching. letting them be for now. All the sets found in the column ISNIFS (in skills but not in found skills) are present in the full skill list but there are errors during pattern matching.

# %%
df1_filtered
# Out:
#       Job Id                                    Job Description  \
# 1          1  overview  reporting to the director of data in...
# 2          2  research associate job locationsus-ma-cambridg...
# 3          3  schneider electric creates connected technolog...
# 4          4    working location:massachusetts, westborough;...
# 5          5  job summary:  the product management professio...
# ...      ...                                                ...
# 2279    2279  auto req id 55553br job code i0857p it busines...
# 2280    2280  auto req id 55453br job code i0758p applicatio...
# 2281    2281  auto req id 54782br job code f0957p financial ...
# 2282    2282  auto req id 54656br job code i0958p it infrast...
# 2283    2283  auto req id 54538br job code i0857p it busines...
#
#                                                  Skills  \
# 1     [Java, Application Architecture, CI, Data Stru...
# 2                                             [Advisor]
# 3                                                    []
# 4     [Data Engineering, Schema Design, Informatica,...
# 5     [Product Requirements, Product Management, Pro...
# ...                                                 ...
# 2279  [Information Systems, HTTP, BI Publisher, SQL,...
# 2280  [Unix, Query Optimization, Java, Methodologies...
# 2281  [Financial Analysis, Accounting, Budget Analys...
# 2282  [HTTP, ITIL, Software Development, HTTPS, Ansi...
# 2283  [User Acceptance Testing, Data Integrity, HTTP...
#
#                                   Tokenized Description  \
# 1     [[overview, reporting, director, data, integra...
# 2     [[research, associate, job, locationsus-ma-cam...
# 3     [[schneider, electric, creates, connected, tec...
# 4     [[working, location, :, massachusetts, ,, west...
# 5     [[job, summary, :, product, management, profes...
# ...                                                 ...
# 2279  [[auto, req, id, 55553br, job, code, i0857p, b...
# 2280  [[auto, req, id, 55453br, job, code, i0758p, a...
# 2281  [[auto, req, id, 54782br, job, code, f0957p, f...
# 2282  [[auto, req, id, 54656br, job, code, i0958p, i...
# 2283  [[auto, req, id, 54538br, job, code, i0857p, b...
#
#                                                    tags  \
# 1     [[O, O, O, B, I, O, O, O, O, O, O, O, O, O, O,...
# 2     [[O, O, O, O, O, O, O, O, O], [O, O, O, O, O, ...
# 3     [[O, O, O, O, O, O, O, O, O, O, O, O, O], [O, ...
# 4     [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 5     [[O, O, O, B, I, O, O, O, O, O, B, O, O, O, O,...
# ...                                                 ...
# 2279  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
# 2280  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2281  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2282  [[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O,...
# 2283  [[O, O, O, O, O, O, O, B, I, O, O, O, O, O, O,...
#
#                                            found_skills  \
# 1     [application development, json, sql, data anal...
# 2     [application development, facebook, cio, twitt...
# 3     [software house, microsoft word, project manag...
# 4     [data science, data engineering, methodologies...
# 5     [product management, product requirements, des...
# ...                                                 ...
# 2279  [critical thinking, sql, https, data analysis,...
# 2280  [programming, debugging, data security, adviso...
# 2281  [budget management, oracle, project cost, micr...
# 2282  [ca, https, drawing, critical thinking, servic...
# 2283  [business analysis, ca, drawing, zoom, advisor...
#
#                                                  ISNIFS
# 1      [databases, software development, framework, ci]
# 2                                                    []
# 3                                                    []
# 4                                    [rdbms, scripting]
# 5                                                    []
# ...                                                 ...
# 2279           [databases, data conversion, frameworks]
# 2280  [oracle, agile, http, problem solving, corona,...
# 2281                                                 []
# 2282  [http, aws, amazon web services (aws), corona,...
# 2283  [data integrity, http, corona, software soluti...
#
# [2283 rows x 7 columns]

# %%
cols_for_modelling = ['Job Id', 'Tokenized Description', 'tags']
df_transformed= df1_filtered[cols_for_modelling]

# %%
df_transformed.to_parquet("transformed_data.parquet")

# %%
model_results=pd.read_parquet("/content/drive/Shareddrives/TM_project/pred_results.parquet")

# %%
# Merging df1_filtered with merged_df_subset
# 'Job Id' in df1_filtered corresponds to 'Job Id Simplified' in merged_df_subset
merged_final_df = df1_filtered.merge(merged_df_subset, left_on='Job Id', right_on='Job Id Simplified')
merged_final_df.to_parquet("merged_data.parquet")
